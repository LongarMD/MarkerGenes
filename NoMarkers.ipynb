# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# %%html
# <style>
# table {
#     float: left;
# }
#
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>
# Out:
# <style>
# table {
#     float: left;
# }
#
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# In this example, we used two datasets of pancreatic cells. For gene markers, we used the Panglao Cell Type Marker database.
#
# We used the Baron (2016) dataset for training the neural network (NN) because it has more cells and classes, and we used the Xin (2016) dataset for testing purposes because all of its classes are present in the Baron dataset.

# %%
EPOCHS = 100

# %%
import saly
import saly.backend as S
from NoMarkers_utility import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


SPECIES = 'Human'
DATA_PATH = '/home/mlongar/Data/SingleCellGeneExpression/'
#DATA_PATH = '/Users/MarkDavidLongar/Documents/Coding/MachineLearning/Data/'
DATA_PATH = 'D:/Data/SingleCellGeneExpression/'
DATASET_BARON_PATH = DATA_PATH + 'baron_2016h.h5ad' 
DATASET_XIN_PATH = DATA_PATH + 'xin_2016.h5ad'
MARKER_PATH = DATA_PATH + 'panglao_gene_markers.tab.gz'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load the data

# %%
baron_data, baron_labels = saly.load_h5ad(DATASET_BARON_PATH)
xin_data, xin_labels = saly.load_h5ad(DATASET_XIN_PATH)

# %% [markdown]
# ### Baron

# %%
print(baron_data.shape)
baron_labels.unique()
# Out:
# (8569, 20125)
# [Acinar cells, Beta cells, Delta cells, PaSC, Ductal cells, Alpha cells, Other, PP cells, Endothelial cell]
# Categories (9, object): [Acinar cells, Beta cells, Delta cells, PaSC, ..., Alpha cells, Other, PP cells, Endothelial cell]

# %% [markdown]
# Baron has 8569 cells and 20125 genes.
#
# The cells are classified into 9 classes: Acinar cells, Alpha cells, Beta cells, Delta cells, Ductal cells, Endothelial cells, ***Other***, PaSC (i.e. Pancreatic stellate cells) and PP cells (i.e. Gamma cells).

# %% [markdown]
# ### Xin

# %%
print(xin_data.shape)
xin_labels.unique()
# Out:
# (1492, 39851)
# [Beta cells, Alpha cells, Delta cells, PP cells]
# Categories (4, object): [Beta cells, Alpha cells, Delta cells, PP cells]

# %% [markdown]
# Xin has 1492 cells and 39851 genes.
#
# The cells are classified into 4 classes: Alpha cells, Beta cells, Delta cells and PP cells (i.e. Gamma cells).

# %% [markdown]
# # Drop rows

# %% [markdown]
# We removed every cell classified as 'Other' from the Baron dataset.

# %%
baron_data, baron_labels = saly.drop_rows(baron_data, baron_labels, ['Other'])
# Out:
# Dropped 118 cell(s). New shape: (8451, 20125)

# %% [markdown]
# This removed 118 cells from Baron, leaving us with 8451 left.

# %% [markdown]
# # Load marker genes

# %% [markdown]
# We make sure to only load the Human marker genes.

# %%
markers_db = saly.load_markers(MARKER_PATH, SPECIES)

# %% [markdown]
# #### Get the markers and only keep those found in both datasets

# %%
markers = saly.get_mutual_markers([baron_data.columns, xin_data.columns], markers_db)

# %% [markdown]
# We do this because we want to train the network only on the marker genes found in both datasets, and drop the rest.

# %%
print(len(S.get_used_markers(baron_data.columns, markers_db)), len(S.get_used_markers(xin_data.columns, markers_db)))
print(len(markers))
# Out:
# 7618 7610
# 7545

# %% [markdown]
# Baron has 7618 markers, and Xin has 7610.
#
# We used only those found in both datasets (7545).

# %% [markdown]
# *Note that in this context* ***Marker ≠ Marker Gene*** *because multiple cell types (i.e. markers) can have the same marker gene and so in this context, the number 7545 means 7545 connections in the partially-connected Marker Layer between the cell types and the genes.*

# %% [markdown]
# ### Make sure every class is in the marker layer

# %% [markdown]
# Because some cell types are differently labelled in the marker database, we created a dictionary of aliases.
#
# We also make sure to print out any label that cannot be found in either the list of markers or in the dictionary of aliases.

# %%
marker_aliases = {'PaSC' : 'Pancreatic stellate cells',
                  'PP cells' : 'Gamma (PP) cells',
                  'Endothelial cell' : 'Endothelial cells'}

saly.check_labels([baron_labels, xin_labels], markers, marker_aliases)

# %% [markdown]
# # Drop unused genes

# %% [markdown]
# We used only the genes found in both datasets and the marker gene database, and therefore, we will connect with the partially-connected marker layer.

# %%
baron_data = saly.drop_unused_genes(baron_data, markers)
xin_data = saly.drop_unused_genes(xin_data, markers)
# Out:
# Dropped 15952 gene(s). New shape: (8451, 4173)
# Dropped 35678 gene(s). New shape: (1492, 4173)

# %% [markdown]
# After this operation we are left with 4173 genes.

# %% [markdown]
# #### Make sure the data sets' shapes match

# %%
saly.check_shape([baron_data, xin_data])

# %% [markdown]
# # Data transformation

# %% [markdown]
# #### Preprocess the data

# %% [markdown]
# We shuffle, log10 transform and split the data into 70%, 15%, 15% splits.

# %%
(train_x, train_y), (validation_x, validation_y), (test_x, test_y) = saly.preprocess_data(baron_data, baron_labels,
                                                                                          train=0.7, validation=0.15,
                                                                                          test=0.15)

# %% [markdown]
# #### Log10 transform the Xin data, too

# %%
xin_data = S.log_10(xin_data)

# %% [markdown]
# # Building the model

# %% [markdown]
# For the model we define a partially-connected Marker Layer.
#
# The layer has a node for each cell type whose genes are present in both data sets.
# In this case, there are 179 nodes in the marker layer representing 179 cell types.
#
# We only connect nodes (i.e. the cell types) in the marker layer to their marker genes at the input.

# %% [markdown]
# We constructed the partially connected marker layer by taking a dense layer and adding a connection mask (a binary matrix) to it, which we multiply with the output matrix.
#
# We trained the network for 100 epochs.

# %% [markdown]
# For training the network we used two losses:
#
#     1) A loss that measured the network's classification accuracy (cross entropy)
#
#     2) A loss that measured the network's reconstruction accuracy (mean square error)
#            During training we scaled the MSE score 100x to compensate for the losses' different scales

# %% [markdown]
# ### The Architecture
# |Layer|Nodes|
# |-----|------|
# |Input|4173 (genes)|
# |Markers|179 (cell types)|
# |Dense layer|100|
# |**Bottleneck**|**25**|
# |Dense layer|100|
# |*Dropout*|*10%*|
# |Output|4173 (genes)|

# %% [markdown]
# #### Create the model

# %%
model, bottleneck_model = build_model(baron_data, markers);

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 4173)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               417400
# _________________________________________________________________
# Bottleneck (Dense)           (None, 25)                2525
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               2600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 4173)              421473
# =================================================================
# Total params: 843,998
# Trainable params: 843,998
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
history = train_model(model, train_x, EPOCHS, validation_data=(validation_x, validation_x), verbose=1);
# Out:
# Train on 5915 samples, validate on 1267 samples
# Epoch 1/100
# 5915/5915 [==============================] - 3s 463us/step - loss: 0.0196 - val_loss: 0.0158
# Epoch 2/100
# 5915/5915 [==============================] - 1s 129us/step - loss: 0.0138 - val_loss: 0.0122
# Epoch 3/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0115 - val_loss: 0.0106
# Epoch 4/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0105 - val_loss: 0.0101
# Epoch 5/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 6/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0098 - val_loss: 0.0096
# Epoch 7/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0096 - val_loss: 0.0094
# Epoch 8/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0095 - val_loss: 0.0093
# Epoch 9/100
# 5915/5915 [==============================] - 1s 129us/step - loss: 0.0093 - val_loss: 0.0092
# Epoch 10/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 11/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0091 - val_loss: 0.0090
# Epoch 12/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 13/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0090 - val_loss: 0.0089
# Epoch 14/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 15/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 16/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 17/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 18/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 19/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 20/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 21/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 22/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 23/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 24/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 25/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 26/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 27/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 28/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 29/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 30/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 31/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 32/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 33/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 34/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 35/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 36/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 37/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 38/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 39/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 40/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 41/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 42/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 43/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 44/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 45/100
# 5915/5915 [==============================] - 1s 129us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 46/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 47/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 48/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 49/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0082 - val_loss: 0.0085
# Epoch 50/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 51/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 52/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 53/100
# 5915/5915 [==============================] - 1s 130us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 54/100
# 5915/5915 [==============================] - 1s 129us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 55/100
# 5915/5915 [==============================] - 1s 129us/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 56/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 57/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 58/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 59/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 60/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 61/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 62/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 63/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 64/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 65/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 66/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 67/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 68/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 69/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 70/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 71/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 72/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 73/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 74/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 75/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 76/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 77/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 78/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 79/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 80/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 81/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 82/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 83/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 84/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 85/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 86/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 87/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 88/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 89/100
# 5915/5915 [==============================] - 1s 126us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 90/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 91/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 92/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 93/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 94/100
# 5915/5915 [==============================] - 1s 127us/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 95/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 96/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 97/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 98/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 99/100
# 5915/5915 [==============================] - 1s 128us/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 100/100
# 5915/5915 [==============================] - 1s 129us/step - loss: 0.0080 - val_loss: 0.0084

# %%
plot_model_history(history)
test_model(model, test_x)
# Out:
# 0.008327254954995793

# %% [markdown]
# # Data analysis

# %%
from sklearn.manifold import TSNE
tsne = TSNE()
colours = S.load_label_colours('Data/baron_xin_label_colours.pickle')

# %% [markdown]
# ## Baron predictions

# %%
baron_cell_activations = model.predict(test_x)
baron_bottleneck_activations = bottleneck_model.predict(test_x)

# %% [markdown]
# The graph below shows the mean cell type activations. Note that only one cell type explicitly activates.

# %%
saly.plot_activation_distribution(baron_bottleneck_activations, markers,
                                  title='Average distribution of Baron cell type activations')

# %% [markdown]
# The network correctly classifies 98% of test data from the training database.

# %%
saly.draw_embedding(baron_bottleneck_activations, test_y, tsne, colours=colours, alpha=0.8,
                    graph_title='tSNE of Baron cell type activations');

# %% [markdown]
# ## Xin predictions

# %%
xin_cell_activations = model.predict(xin_data)
xin_bottleneck_activations = bottleneck_model.predict(xin_data)

# %%
saly.plot_activation_distribution(xin_bottleneck_activations, markers,
                                  title='Average distribution of Xin cell type activations')

# %% [markdown]
# The network correctly classifies almost 100% of data from a completely new data set.

# %%
saly.draw_embedding(xin_cell_activations, xin_labels, tsne, colours=colours, alpha=0.8,
                    graph_title='TSNE of Xin cell type activations');

# %% [markdown]
# # Combined data

# %% [markdown]
# Here we see if our marker activations still have batch effects.

# %%
saly.draw_comparison([baron_cell_activations, test_y], [xin_cell_activations, xin_labels] ,tsne, colours=colours,
                     graph_title='Combined cell activations of Baron and Xin cell type activations')

# %% [markdown]
# # Top 3 activations

# %% [markdown]
# We also tried to see if taking only the top 3 cell activations would help us remedy the batch effect.

# %%
baron_top_3 = saly.get_top_activations(3, baron_bottleneck_activations)
xin_top_3 = saly.get_top_activations(3, xin_bottleneck_activations)

# %%
saly.draw_comparison([baron_top_3, test_y], [xin_top_3, xin_labels], tsne, colours=colours,
                     graph_title='Combined data of top 3 activations of Baron and Xin')

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# %%html
# <style>
# table {
#     float: left;
# }
#
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>
# Out:
# <style>
# table {
#     float: left;
# }
#
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# In this example, we used two datasets of pancreatic cells. For gene markers, we used the Panglao Cell Type Marker database.
#
# We used the Baron (2016) dataset for training the neural network (NN) because it has more cells and classes, and we used the Xin (2016) dataset for testing purposes because all of its classes are present in the Baron dataset.

# %%
EPOCHS = 100

# %%
import saly
import saly.backend as S
from NoAE_utility import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


SPECIES = 'Human'
DATA_PATH = '/home/mlongar/Data/SingleCellGeneExpression/'
#DATA_PATH = '/Users/MarkDavidLongar/Documents/Coding/MachineLearning/Data/'
DATA_PATH = 'D:/Data/SingleCellGeneExpression/'
DATASET_BARON_PATH = DATA_PATH + 'baron_2016h.h5ad' 
DATASET_XIN_PATH = DATA_PATH + 'xin_2016.h5ad'
MARKER_PATH = DATA_PATH + 'panglao_gene_markers.tab.gz'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load the data

# %%
baron_data, baron_labels = saly.load_h5ad(DATASET_BARON_PATH)
xin_data, xin_labels = saly.load_h5ad(DATASET_XIN_PATH)

# %% [markdown]
# ### Baron

# %%
print(baron_data.shape)
baron_labels.unique()
# Out:
# (8569, 20125)
# [Acinar cells, Beta cells, Delta cells, PaSC, Ductal cells, Alpha cells, Other, PP cells, Endothelial cell]
# Categories (9, object): [Acinar cells, Beta cells, Delta cells, PaSC, ..., Alpha cells, Other, PP cells, Endothelial cell]

# %% [markdown]
# Baron has 8569 cells and 20125 genes.
#
# The cells are classified into 9 classes: Acinar cells, Alpha cells, Beta cells, Delta cells, Ductal cells, Endothelial cells, ***Other***, PaSC (i.e. Pancreatic stellate cells) and PP cells (i.e. Gamma cells).

# %% [markdown]
# ### Xin

# %%
print(xin_data.shape)
xin_labels.unique()
# Out:
# (1492, 39851)
# [Beta cells, Alpha cells, Delta cells, PP cells]
# Categories (4, object): [Beta cells, Alpha cells, Delta cells, PP cells]

# %% [markdown]
# Xin has 1492 cells and 39851 genes.
#
# The cells are classified into 4 classes: Alpha cells, Beta cells, Delta cells and PP cells (i.e. Gamma cells).

# %% [markdown]
# # Drop rows

# %% [markdown]
# We removed every cell classified as 'Other' from the Baron dataset.

# %%
baron_data, baron_labels = saly.drop_rows(baron_data, baron_labels, ['Other'])
# Out:
# Dropped 118 cell(s). New shape: (8451, 20125)

# %% [markdown]
# This removed 118 cells from Baron, leaving us with 8451 left.

# %% [markdown]
# # Load marker genes

# %% [markdown]
# We make sure to only load the Human marker genes.

# %%
markers_db = saly.load_markers(MARKER_PATH, SPECIES)

# %% [markdown]
# #### Get the markers and only keep those found in both datasets

# %%
markers = saly.get_mutual_markers([baron_data.columns, xin_data.columns], markers_db)

# %% [markdown]
# We do this because we want to train the network only on the marker genes found in both datasets, and drop the rest.

# %%
print(len(S.get_used_markers(baron_data.columns, markers_db)), len(S.get_used_markers(xin_data.columns, markers_db)))
print(len(markers))
# Out:
# 7618 7610
# 7545

# %% [markdown]
# Baron has 7618 markers, and Xin has 7610.
#
# We used only those found in both datasets (7545).

# %% [markdown]
# *Note that in this context* ***Marker ≠ Marker Gene*** *because multiple cell types (i.e. markers) can have the same marker gene and so in this context, the number 7545 means 7545 connections in the partially-connected Marker Layer between the cell types and the genes.*

# %% [markdown]
# ### Make sure every class is in the marker layer

# %% [markdown]
# Because some cell types are differently labelled in the marker database, we created a dictionary of aliases.
#
# We also make sure to print out any label that cannot be found in either the list of markers or in the dictionary of aliases.

# %%
marker_aliases = {'PaSC' : 'Pancreatic stellate cells',
                  'PP cells' : 'Gamma (PP) cells',
                  'Endothelial cell' : 'Endothelial cells'}

saly.check_labels([baron_labels, xin_labels], markers, marker_aliases)

# %% [markdown]
# # Drop unused genes

# %% [markdown]
# We used only the genes found in both datasets and the marker gene database, and therefore, we will connect with the partially-connected marker layer.

# %%
baron_data = saly.drop_unused_genes(baron_data, markers)
xin_data = saly.drop_unused_genes(xin_data, markers)
# Out:
# Dropped 15952 gene(s). New shape: (8451, 4173)
# Dropped 35678 gene(s). New shape: (1492, 4173)

# %% [markdown]
# After this operation we are left with 4173 genes.

# %% [markdown]
# #### Make sure the data sets' shapes match

# %%
saly.check_shape([baron_data, xin_data])

# %% [markdown]
# # Data transformation

# %% [markdown]
# #### Preprocess the data

# %% [markdown]
# We shuffle, log10 transform and split the data into 70%, 15%, 15% splits.

# %%
(train_x, train_y), (validation_x, validation_y), (test_x, test_y) = saly.preprocess_data(baron_data, baron_labels,
                                                                                          train=0.7, validation=0.15,
                                                                                          test=0.15)

# %% [markdown]
# #### Log10 transform the Xin data, too

# %%
xin_data = S.log_10(xin_data)

# %% [markdown]
# # Building the model

# %% [markdown]
# For the model we define a partially-connected Marker Layer.
#
# The layer has a node for each cell type whose genes are present in both data sets.
# In this case, there are 179 nodes in the marker layer representing 179 cell types.
#
# We only connect nodes (i.e. the cell types) in the marker layer to their marker genes at the input.

# %% [markdown]
# We constructed the partially connected marker layer by taking a dense layer and adding a connection mask (a binary matrix) to it, which we multiply with the output matrix.
#
# We trained the network for 100 epochs.

# %% [markdown]
# For training the network we used two losses:
#
#     1) A loss that measured the network's classification accuracy (cross entropy)
#
#     2) A loss that measured the network's reconstruction accuracy (mean square error)
#            During training we scaled the MSE score 100x to compensate for the losses' different scales

# %% [markdown]
# ### The Architecture
# |Layer|Nodes|
# |-----|------|
# |Input|4173 (genes)|
# |Markers|179 (cell types)|
# |Dense layer|100|
# |**Bottleneck**|**25**|
# |Dense layer|100|
# |*Dropout*|*10%*|
# |Output|4173 (genes)|

# %% [markdown]
# #### Create the model

# %%
model = build_model(baron_data, markers);

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 4173)              0
# _________________________________________________________________
# cell_activations (Markers)   (None, 179)               747146
# =================================================================
# Total params: 747,146
# Trainable params: 747,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
history = train_model(model, train_x, train_y, markers, marker_aliases,
                           EPOCHS, validation_data=(validation_x, validation_y), verbose=1);
# Out:
# Train on 5915 samples, validate on 1267 samples
# Epoch 1/100
# 5915/5915 [==============================] - 1s 165us/step - loss: 4.9880 - val_loss: 4.7428
# Epoch 2/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 4.5306 - val_loss: 4.2959
# Epoch 3/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 4.0878 - val_loss: 3.8713
# Epoch 4/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 3.6751 - val_loss: 3.4822
# Epoch 5/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 3.3052 - val_loss: 3.1334
# Epoch 6/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 2.9764 - val_loss: 2.8206
# Epoch 7/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 2.6796 - val_loss: 2.5367
# Epoch 8/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 2.4118 - val_loss: 2.2794
# Epoch 9/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 2.1701 - val_loss: 2.0503
# Epoch 10/100
# 5915/5915 [==============================] - 0s 71us/step - loss: 1.9549 - val_loss: 1.8468
# Epoch 11/100
# 5915/5915 [==============================] - 0s 71us/step - loss: 1.7649 - val_loss: 1.6689
# Epoch 12/100
# 5915/5915 [==============================] - 0s 71us/step - loss: 1.5983 - val_loss: 1.5136
# Epoch 13/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 1.4529 - val_loss: 1.3783
# Epoch 14/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 1.3264 - val_loss: 1.2603
# Epoch 15/100
# 5915/5915 [==============================] - 0s 72us/step - loss: 1.2158 - val_loss: 1.1576
# Epoch 16/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 1.1193 - val_loss: 1.0673
# Epoch 17/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 1.0344 - val_loss: 0.9880
# Epoch 18/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.9596 - val_loss: 0.9182
# Epoch 19/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.8930 - val_loss: 0.8558
# Epoch 20/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.8334 - val_loss: 0.7998
# Epoch 21/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.7803 - val_loss: 0.7498
# Epoch 22/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.7327 - val_loss: 0.7051
# Epoch 23/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.6900 - val_loss: 0.6652
# Epoch 24/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.6516 - val_loss: 0.6288
# Epoch 25/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.6165 - val_loss: 0.5960
# Epoch 26/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.5847 - val_loss: 0.5660
# Epoch 27/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.5559 - val_loss: 0.5389
# Epoch 28/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.5295 - val_loss: 0.5139
# Epoch 29/100
# 5915/5915 [==============================] - 0s 71us/step - loss: 0.5050 - val_loss: 0.4909
# Epoch 30/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.4826 - val_loss: 0.4697
# Epoch 31/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.4619 - val_loss: 0.4500
# Epoch 32/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.4426 - val_loss: 0.4320
# Epoch 33/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.4250 - val_loss: 0.4155
# Epoch 34/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.4087 - val_loss: 0.4001
# Epoch 35/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.3935 - val_loss: 0.3857
# Epoch 36/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.3793 - val_loss: 0.3723
# Epoch 37/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.3661 - val_loss: 0.3601
# Epoch 38/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.3539 - val_loss: 0.3486
# Epoch 39/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.3424 - val_loss: 0.3376
# Epoch 40/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.3315 - val_loss: 0.3276
# Epoch 41/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.3214 - val_loss: 0.3180
# Epoch 42/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.3119 - val_loss: 0.3089
# Epoch 43/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.3029 - val_loss: 0.3004
# Epoch 44/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2944 - val_loss: 0.2925
# Epoch 45/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2864 - val_loss: 0.2849
# Epoch 46/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2788 - val_loss: 0.2778
# Epoch 47/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.2717 - val_loss: 0.2710
# Epoch 48/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2648 - val_loss: 0.2647
# Epoch 49/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2584 - val_loss: 0.2586
# Epoch 50/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2523 - val_loss: 0.2529
# Epoch 51/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2464 - val_loss: 0.2473
# Epoch 52/100
# 5915/5915 [==============================] - 0s 71us/step - loss: 0.2408 - val_loss: 0.2421
# Epoch 53/100
# 5915/5915 [==============================] - 0s 71us/step - loss: 0.2355 - val_loss: 0.2372
# Epoch 54/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2304 - val_loss: 0.2324
# Epoch 55/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2255 - val_loss: 0.2278
# Epoch 56/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2209 - val_loss: 0.2235
# Epoch 57/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2165 - val_loss: 0.2193
# Epoch 58/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.2123 - val_loss: 0.2154
# Epoch 59/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2082 - val_loss: 0.2115
# Epoch 60/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2043 - val_loss: 0.2078
# Epoch 61/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.2005 - val_loss: 0.2043
# Epoch 62/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.1969 - val_loss: 0.2009
# Epoch 63/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1933 - val_loss: 0.1975
# Epoch 64/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1900 - val_loss: 0.1944
# Epoch 65/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1867 - val_loss: 0.1913
# Epoch 66/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1837 - val_loss: 0.1884
# Epoch 67/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1807 - val_loss: 0.1856
# Epoch 68/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1778 - val_loss: 0.1829
# Epoch 69/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1750 - val_loss: 0.1803
# Epoch 70/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1723 - val_loss: 0.1779
# Epoch 71/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1698 - val_loss: 0.1755
# Epoch 72/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1673 - val_loss: 0.1732
# Epoch 73/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1649 - val_loss: 0.1710
# Epoch 74/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1625 - val_loss: 0.1689
# Epoch 75/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1603 - val_loss: 0.1668
# Epoch 76/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1582 - val_loss: 0.1647
# Epoch 77/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1560 - val_loss: 0.1627
# Epoch 78/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1540 - val_loss: 0.1608
# Epoch 79/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1520 - val_loss: 0.1589
# Epoch 80/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1501 - val_loss: 0.1571
# Epoch 81/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.1482 - val_loss: 0.1554
# Epoch 82/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1464 - val_loss: 0.1537
# Epoch 83/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1447 - val_loss: 0.1521
# Epoch 84/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1430 - val_loss: 0.1505
# Epoch 85/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.1413 - val_loss: 0.1489
# Epoch 86/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1396 - val_loss: 0.1474
# Epoch 87/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1381 - val_loss: 0.1459
# Epoch 88/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1366 - val_loss: 0.1445
# Epoch 89/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1351 - val_loss: 0.1432
# Epoch 90/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1337 - val_loss: 0.1418
# Epoch 91/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1322 - val_loss: 0.1404
# Epoch 92/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1309 - val_loss: 0.1392
# Epoch 93/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.1295 - val_loss: 0.1380
# Epoch 94/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1282 - val_loss: 0.1368
# Epoch 95/100
# 5915/5915 [==============================] - 0s 71us/step - loss: 0.1270 - val_loss: 0.1355
# Epoch 96/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1257 - val_loss: 0.1343
# Epoch 97/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1245 - val_loss: 0.1332
# Epoch 98/100
# 5915/5915 [==============================] - 0s 69us/step - loss: 0.1233 - val_loss: 0.1320
# Epoch 99/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1222 - val_loss: 0.1309
# Epoch 100/100
# 5915/5915 [==============================] - 0s 70us/step - loss: 0.1211 - val_loss: 0.1300

# %%
saly.plot_model_history(history)
saly.test_model(model, test_x, test_y, markers, marker_aliases);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-a930a0bba7e7> in <module>
# ----> 1 saly.plot_model_history(history)
#       2 saly.test_model(model, test_x, test_y, markers, marker_aliases);
#
# D:\Development\MarkerGenes\saly\deep\analysis.py in plot_model_history(history)
#      41     """
#      42     fig, (ax1, ax2) = plt.subplots(2, 1, sharex='all', figsize=(7, 7), dpi=80)
# ---> 43     output_loss = history.history['output_loss']
#      44     output_loss = [i * 100 for i in output_loss]
#      45
#
# KeyError: 'output_loss'

# %% [markdown]
# # Data analysis

# %%
from sklearn.manifold import TSNE
tsne = TSNE()
colours = S.load_label_colours('Data/baron_xin_label_colours.pickle')

# %% [markdown]
# ## Baron predictions

# %%
baron_cell_activations = model.predict(test_x)

# %% [markdown]
# The graph below shows the mean cell type activations. Note that only one cell type explicitly activates.

# %%
saly.plot_activation_distribution(baron_cell_activations, markers,
                                  title='Average distribution of Baron cell type activations')

# %%
saly.get_results(test_y, baron_cell_activations, markers, marker_aliases)
# Out:
# Correct predictions: 2479 out of 2536 (97.75%)

# %% [markdown]
# The network correctly classifies 98% of test data from the training database.

# %%
saly.draw_embedding(baron_cell_activations, test_y, tsne, colours=colours, alpha=0.8,
                    graph_title='tSNE of Baron cell type activations');

# %% [markdown]
# ## Xin predictions

# %%
xin_cell_activations = model.predict(xin_data)

# %%
saly.plot_activation_distribution(xin_cell_activations, markers,
                                  title='Average distribution of Xin cell type activations')

# %%
saly.get_results(xin_labels, xin_cell_activations, markers, marker_aliases)
# Out:
# Correct predictions: 1488 out of 1492 (99.73%)

# %% [markdown]
# The network correctly classifies almost 100% of data from a completely new data set.

# %%
saly.draw_embedding(xin_cell_activations, xin_labels, tsne, colours=colours, alpha=0.8,
                    graph_title='TSNE of Xin cell type activations');

# %% [markdown]
# # Combined data

# %% [markdown]
# Here we see if our marker activations still have batch effects.

# %%
saly.draw_comparison([baron_cell_activations, test_y], [xin_cell_activations, xin_labels] ,tsne, colours=colours,
                     graph_title='Combined cell activations of Baron and Xin cell type activations')

# %% [markdown]
# # Top 3 activations

# %% [markdown]
# We also tried to see if taking only the top 3 cell activations would help us remedy the batch effect.

# %%
baron_top_3 = saly.get_top_activations(3, baron_cell_activations)
xin_top_3 = saly.get_top_activations(3, xin_cell_activations)

# %%
saly.draw_comparison([baron_top_3, test_y], [xin_top_3, xin_labels], tsne, colours=colours,
                     graph_title='Combined data of top 3 activations of Baron and Xin')

# %%
import tensorflow as tf
from os import path
import sys
tf.logging.set_verbosity(tf.logging.ERROR)
sys.path.append(path.join("../.."))

# %%
# %%html
# <style>
# table {
#     float: left;
# }
#
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>
# Out:
# <style>
# table {
#     float: left;
# }
#
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# In this example, we used two datasets of mouse brain cells. For gene markers, we used the Panglao Cell Type Marker database.
#
# We used the Hrvatin (2018) dataset for training the neural network (NN) because it has more cells and classes, and we used the Chen (2017) dataset for testing purposes because all of its classes are present in the Hrvatin dataset.

# %%
EPOCHS = 35

# %%
# %load_ext autoreload
# %autoreload 2

import saly
import saly.backend as S
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


SPECIES = 'Mouse'
DATA_PATH = '/home/mlongar/Data/SingleCellGeneExpression/'
#DATA_PATH = '/Users/MarkDavidLongar/Documents/Coding/MachineLearning/Data/'
#DATA_PATH = 'D:/Data/SingleCellGeneExpression/'
DATASET_HRVATIN_PATH = DATA_PATH + 'hrvatin_2018.h5ad' 
DATASET_CHEN_PATH = DATA_PATH + 'chen_2017.h5ad'
DATASET_BIG_PATH = DATA_PATH + '10x_mouse_1.3mln.h5ad'
MARKER_PATH = DATA_PATH + 'panglao_gene_markers.tab.gz'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load the data

# %%
hrvatin_data, hrvatin_labels = saly.load_h5ad(DATASET_HRVATIN_PATH)
chen_data, chen_labels = saly.load_h5ad(DATASET_CHEN_PATH)
big_data, big_labels = saly.load_h5ad(DATASET_BIG_PATH)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-6ef3745357eb> in <module>
#       1 hrvatin_data, hrvatin_labels = saly.load_h5ad(DATASET_HRVATIN_PATH)
#       2 chen_data, chen_labels = saly.load_h5ad(DATASET_CHEN_PATH)
# ----> 3 big_data, big_labels = saly.load_h5ad(DATASET_BIG_PATH)
#
# ~/MarkerGenes/saly/deep/data.py in load_h5ad(path)
#      14     dataset = read_h5ad(path)
#      15     labels = dataset.obs["labels"]
# ---> 16     dataset = dataset.to_df()
#      17
#      18     return dataset, labels
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/anndata/core/anndata.py in to_df(self)
#    1420         """
#    1421         if issparse(self._X):
# -> 1422             X = self._X.toarray()
#    1423         else:
#    1424             X = self._X
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/scipy/sparse/compressed.py in toarray(self, order, out)
#    1022         if out is None and order is None:
#    1023             order = self._swap('cf')[0]
# -> 1024         out = self._process_toarray_args(order, out)
#    1025         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1026             raise ValueError('Output array must be C or F contiguous')
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/scipy/sparse/base.py in _process_toarray_args(self, order, out)
#    1184             return out
#    1185         else:
# -> 1186             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1187
#    1188
#
# MemoryError:

# %% [markdown]
# ### Hrvatin

# %%
print(hrvatin_data.shape)
hrvatin_labels.value_counts()
# Out:
# (48266, 25186)
# Neuron              15223
# Microglia           10158
# Oligodendrocyte      8630
# Astrocyte            7039
# Endothelial cell     3450
# OPC                  1826
# Pericyte              782
# Muscle cell           621
# Macrophage            537
# Name: labels, dtype: int64

# %% [markdown]
# Hrvatin has 48 266 cells and 25 186 genes.
#
# The cells are classified into 9 classes: Neuron, Oligodendrocyte, Muscle cell, Astrocyte, Endothelial cell, Macrophage, Microglia, OPC and Pericyte.

# %% [markdown]
# ### Chen

# %%
print(chen_data.shape)
chen_labels.value_counts()
# Out:
# (14437, 23284)
# Oligodendrocyte    3541
# unknown            2531
# Neuron             2315
# OPC                1792
# epithelial cell    1197
# Astrocyte          1148
# Microglia           724
# tanycyte            609
# ependymal cell      413
# Macrophage          167
# Name: labels, dtype: int64

# %% [markdown]
# Chen has 14 437 cells and 39 851 genes.
#
# The cells are classified into 10 classes: tanycyte, Neuron, unknown, ependymal cell, Oligodendrocyte, epithelial cell, OPC, Astrocyte, Microglia and Macrophage.

# %% [markdown]
# ## Big data

# %%
print(big_data.shape)
# Out:
# (1306127, 27932)

# %% [markdown]
# # Drop rows

# %% [markdown]
# We removed every cell classified as 'unknown' from the Chen dataset and we also removed every cell type not found in the Hrvatin data set.

# %%
unseen = ['Oligodendrocyte', 'Macrophage']
hrvatin_data, hrvatin_labels = saly.drop_rows(hrvatin_data, hrvatin_labels, unseen)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-3074b7a03543> in <module>
#       1 unseen = ['Oligodendrocyte', 'Macrophage']
# ----> 2 hrvatin_data, hrvatin_labels = saly.drop_rows(hrvatin_data, hrvatin_labels, unseen)
#
# ~/MarkerGenes/saly/deep/data.py in drop_rows(data, labels, row_names)
#      73     to_drop = backend.get_rows_to_drop(row_names, labels)
#      74
# ---> 75     data = data.drop(data.index[to_drop], axis=0)
#      76     labels = labels.drop(labels.index[to_drop], axis=0)
#      77
#
# AttributeError: 'AnnData' object has no attribute 'drop'

# %%
chen_unique = chen_labels.unique().to_list()
unseen_data, unseen_labels = saly.drop_rows(chen_data, chen_labels, [e for e in chen_unique if e not in unseen])

chen_data, chen_labels = saly.drop_rows(chen_data, chen_labels,
                                        ['tanycyte', 'unknown', 'ependymal cell', 'epithelial cell',
                                         'Oligodendrocyte', 'Macrophage'])
# Out:
# Dropped 10729 cell(s). New shape: (3708, 23284)
# Dropped 8458 cell(s). New shape: (5979, 23284)

# %% [markdown]
# This removed 4750  cells from Chen, leaving us with 9687 left.

# %% [markdown]
# # Load marker genes

# %% [markdown]
# We make sure to only load the Human marker genes.

# %%
markers_db = saly.load_markers(MARKER_PATH, SPECIES)

# %% [markdown]
# #### Get the markers and only keep those found in both datasets

# %%
markers = saly.get_mutual_markers([hrvatin_data.columns, chen_data.columns, big_data_columns], markers_db)

# %% [markdown]
# We do this because we want to train the network only on the marker genes found in both datasets, and drop the rest.

# %%
#print(len(S.get_used_markers(hrvatin_data.columns, markers_db)), len(S.get_used_markers(chen_data.columns, markers_db)))
print(len(markers))
# Out:
# 7384

# %% [markdown]
# Hrvatin has 7675  markers, and Chen has 7477.
#
# We used only those found in both datasets (7390).

# %% [markdown]
# *Note that in this context* ***Marker ≠ Marker Gene*** *because multiple cell types (i.e. markers) can have the same marker gene and so in this context, the number 7545 means 7545 connections in the partially-connected Marker Layer between the cell types and the genes.*

# %% [markdown]
# ### Make sure every class is in the marker layer

# %% [markdown]
# Because some cell types are differently labelled in the marker database, we created a dictionary of aliases.
#
# We also make sure to print out any label that cannot be found in either the list of markers or in the dictionary of aliases.

# %%
marker_aliases = {'Neuron' : 'Neurons',
                'Oligodendrocyte' : 'Oligodendrocytes',
                'Muscle cell' : 'Smooth muscle cells',
                'Endothelial cell' : 'Endothelial cells',
                'Astrocyte' : 'Astrocytes',
                'Macrophage' : 'Macrophages',
                'OPC' : 'Oligodendrocyte progenitor cells',
                'Pericyte' : 'Pericytes',
                'ependymal cell' : 'Ependymal cells',
                'epithelial cell' : 'Epithelial cells',
                'tanycyte' : 'Tanycytes'}

saly.check_labels([hrvatin_labels, chen_labels], markers, marker_aliases)

# %% [markdown]
# # Drop unused genes

# %% [markdown]
# We used only the genes found in both datasets and the marker gene database, and therefore, we will connect with the partially-connected marker layer.

# %%
hrvatin_data = saly.drop_unused_genes(hrvatin_data, markers)
chen_data = saly.drop_unused_genes(chen_data, markers)
unseen_data = saly.drop_unused_genes(unseen_data, markers)
# Out:
# Dropped 21104 gene(s). New shape: (39099, 4082)
# Dropped 19202 gene(s). New shape: (5979, 4082)
# Dropped 19202 gene(s). New shape: (3708, 4082)

# %% [markdown]
# After this operation we are left with 4082 genes.

# %% [markdown]
# #### Make sure the data sets' shapes match

# %%
saly.check_shape([hrvatin_data, chen_data, unseen_data])

# %% [markdown]
# # Data transformation

# %% [markdown]
# #### Preprocess the data

# %% [markdown]
# We shuffle, log10 transform and split the data into 70%, 15%, 15% splits.

# %%
(train_x, train_y), (validation_x, validation_y), (test_x, test_y) = saly.preprocess_data(hrvatin_data, hrvatin_labels,
                                                                                          train=0.7, validation=0.15,
                                                                                          test=0.15)

# %% [markdown]
# #### Log10 transform the Chen data, too

# %%
chen_data = S.log_10(chen_data)
unseen_data = S.log_10(unseen_data)

# %% [markdown]
# # Building the model

# %% [markdown]
# For the model we define a partially-connected Marker Layer.
#
# The layer has a node for each cell type whose genes are present in both data sets.
# In this case, there are 179 nodes in the marker layer representing 179 cell types.
#
# We only connect nodes (i.e. the cell types) in the marker layer to their marker genes at the input.

# %% [markdown]
# We constructed the partially connected marker layer by taking a dense layer and adding a connection mask (a binary matrix) to it, which we multiply with the output matrix.
#
# We trained the network for 100 epochs.

# %% [markdown]
# For training the network we used two losses:
#
#     1) A loss that measured the network's classification accuracy (cross entropy)
#
#     2) A loss that measured the network's reconstruction accuracy (mean square error)
#            During training we scaled the MSE score 100x to compensate for the losses' different scales

# %% [markdown]
# ### The Architecture
# |Layer|Nodes|
# |-----|------|
# |Input|4082 (genes)|
# |Markers|179 (cell types)|
# |Dense layer|100|
# |**Bottleneck**|**25**|
# |Dense layer|100|
# |*Dropout*|*10%*|
# |Output|4082 (genes)|

# %% [markdown]
# #### Create the model

# %%
model, marker_model, encoder_model = saly.build_model(hrvatin_data, markers, supervised=False);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b0ba426a5233> in <module>
# ----> 1 model, marker_model, encoder_model = saly.build_model(hrvatin_data, markers, supervised=False);
#
# NameError: name 'markers' is not defined

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 4082)              0
# _________________________________________________________________
# partial_3 (Partial)          (None, 844)               3445208
# _________________________________________________________________
# cell_activations (Partial)   (None, 179)               151076
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               18000
# _________________________________________________________________
# Bottleneck (Dense)           (None, 25)                2525
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               2600
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 4082)              412282
# =================================================================
# Total params: 4,031,691
# Trainable params: 4,031,691
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
history = saly.train_model(model, train_x, train_y, markers, marker_aliases,
                           EPOCHS, validation_data=(unseen_data, unseen_labels), verbose=1);
# Out:
# Train on 27369 samples, validate on 3708 samples
# Epoch 1/35
# 27369/27369 [==============================] - 12s 428us/step - loss: 43.7022 - cell_activations_loss: 0.0000e+00 - output_loss: 0.0437 - cell_activations_marker_prediction_metric: 0.9318 - val_loss: 15.4058 - val_cell_activations_loss: 0.0000e+00 - val_output_loss: 0.0154 - val_cell_activations_marker_prediction_metric: 0.9763
# Epoch 2/35
# 27369/27369 [==============================] - 9s 346us/step - loss: 12.3689 - cell_activations_loss: 0.0000e+00 - output_loss: 0.0124 - cell_activations_marker_prediction_metric: 0.9319 - val_loss: 14.6443 - val_cell_activations_loss: 0.0000e+00 - val_output_loss: 0.0146 - val_cell_activations_marker_prediction_metric: 0.9763
# Epoch 3/35
# 27369/27369 [==============================] - 10s 351us/step - loss: 11.8779 - cell_activations_loss: 0.0000e+00 - output_loss: 0.0119 - cell_activations_marker_prediction_metric: 0.9320 - val_loss: 13.9583 - val_cell_activations_loss: 0.0000e+00 - val_output_loss: 0.0140 - val_cell_activations_marker_prediction_metric: 0.9763
# Epoch 4/35
# 27369/27369 [==============================] - 10s 361us/step - loss: 11.4858 - cell_activations_loss: 0.0000e+00 - output_loss: 0.0115 - cell_activations_marker_prediction_metric: 0.9320 - val_loss: 13.9099 - val_cell_activations_loss: 0.0000e+00 - val_output_loss: 0.0139 - val_cell_activations_marker_prediction_metric: 0.9763
# Epoch 5/35
# 27369/27369 [==============================] - 10s 356us/step - loss: 11.0300 - cell_activations_loss: 0.0000e+00 - output_loss: 0.0110 - cell_activations_marker_prediction_metric: 0.9320 - val_loss: 13.8115 - val_cell_activations_loss: 0.0000e+00 - val_output_loss: 0.0138 - val_cell_activations_marker_prediction_metric: 0.9763
# Epoch 6/35
# 27369/27369 [==============================] - 10s 366us/step - loss: 10.7301 - cell_activations_loss: 0.0000e+00 - output_loss: 0.0107 - cell_activations_marker_prediction_metric: 0.9321 - val_loss: 13.6825 - val_cell_activations_loss: 0.0000e+00 - val_output_loss: 0.0137 - val_cell_activations_marker_prediction_metric: 0.9763
# Epoch 7/35
# 18432/27369 [===================>..........] - ETA: 3s - loss: 10.5404 - cell_activations_loss: 0.0000e+00 - output_loss: 0.0105 - cell_activations_marker_prediction_metric: 0.9311
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-62ce7855c07c> in <module>
#       1 history = saly.train_model(model, train_x, train_y, markers, marker_aliases,
# ----> 2                            EPOCHS, validation_data=(unseen_data, unseen_labels), verbose=1);
#
# ~/MarkerGenes/saly/deep/model.py in train_model(model, data, labels, markers, marker_aliases, epochs, validation_data, batch_size, verbose, callbacks)
#      80                         validation_data=validation_data,
#      81                         callbacks=callbacks,
# ---> 82                         verbose=verbose)
#      83
#      84     return history
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     183                         # Do not slice the training phase flag.
#     184                         ins_batch = slice_arrays(
# --> 185                             ins[:-1], batch_ids) + [ins[-1]]
#     186                     else:
#     187                         ins_batch = slice_arrays(ins, batch_ids)
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/keras/utils/generic_utils.py in slice_arrays(arrays, start, stop)
#     524             if hasattr(start, 'shape'):
#     525                 start = start.tolist()
# --> 526             return [None if x is None else x[start] for x in arrays]
#     527         else:
#     528             return [None if x is None else x[start:stop] for x in arrays]
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/keras/utils/generic_utils.py in <listcomp>(.0)
#     524             if hasattr(start, 'shape'):
#     525                 start = start.tolist()
# --> 526             return [None if x is None else x[start] for x in arrays]
#     527         else:
#     528             return [None if x is None else x[start:stop] for x in arrays]
#
# KeyboardInterrupt:

# %%
saly.plot_model_history(history, supervised=True)
saly.test_model(model, test_x, test_y, markers, marker_aliases);

# %% [markdown]
# # Data analysis

# %%
from sklearn.manifold import TSNE
tsne = TSNE()
colours = S.load_label_colours('../Data/hrvatin_chen_label_colours.pickle')

# %% [markdown]
# ## Hrvatin predictions

# %%
hrvatin_cell_activations = marker_model.predict(test_x)
hrvatin_bottleneck_activations = encoder_model.predict(test_x)

# %%
saly.get_results(test_y, hrvatin_cell_activations, markers, marker_aliases)
# Out:
# Correct predictions: 11414 out of 11730 (97.31%)

# %%
saly.get_average_auc(test_y, hrvatin_cell_activations, markers, marker_aliases)
# Out:
# /home/mlongar/miniconda/envs/MG/lib/python3.7/site-packages/sklearn/metrics/ranking.py:659: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# Average ROC AUC: 0.503

# %% [markdown]
# The graph below shows the mean cell type activations. Note that only one cell type explicitly activates.

# %%
saly.draw_confusion_matrix(test_y, hrvatin_cell_activations, markers, marker_aliases)

# %%
saly.plot_activation_distribution(hrvatin_cell_activations, markers,
                                  title='Average distribution of Hrvatin cell type activations')

# %% [markdown]
# ## Unseen Types

# %%
unseen_cell_activations = marker_model.predict(unseen_data)

# %%
saly.get_results(unseen_labels, unseen_cell_activations, markers, marker_aliases)
# Out:
# Correct predictions: 3622 out of 3708 (97.68%)

# %%
saly.get_average_auc(unseen_labels, unseen_cell_activations, markers, marker_aliases)
# Out:
# Average ROC AUC: 0.5

# %%
saly.draw_confusion_matrix(unseen_labels, unseen_cell_activations, markers, marker_aliases)

# %%
saly.plot_activation_distribution(unseen_cell_activations, markers,
                                  title='Average distribution of unseen cell type activations')

# %%
saly.draw_comparison([hrvatin_cell_activations, test_y], [unseen_cell_activations, unseen_labels],
                     tsne, colours=colours,
                     graph_title='Combined cell activations of hrvatin and unseen cell type activations')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-2076acf717b3> in <module>
#       1 saly.draw_comparison([hrvatin_cell_activations, test_y], [unseen_cell_activations, unseen_labels],
#       2                      tsne, colours=colours,
# ----> 3                      graph_title='Combined cell activations of hrvatin and unseen cell type activations')
#
# ~/MarkerGenes/saly/deep/analysis.py in draw_comparison(old, new, model, colours, graph_title)
#     291
#     292     x = np.concatenate((old[0], new[0]), axis=0)
# --> 293     model_out = model.fit_transform(x)
#     294
#     295     plt.figure(figsize=(8, 8), dpi=80)
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     893             Embedding of the training data in low-dimensional space.
#     894         """
# --> 895         embedding = self._fit(X)
#     896         self.embedding_ = embedding
#     897         return self.embedding_
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     766             t0 = time()
#     767             distances_nn, neighbors_nn = knn.kneighbors(
# --> 768                 None, n_neighbors=k)
#     769             duration = time() - t0
#     770             if self.verbose:
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/sklearn/neighbors/base.py in kneighbors(self, X, n_neighbors, return_distance)
#     452                 delayed_query(
#     453                     self._tree, X[s], n_neighbors, return_distance)
# --> 454                 for s in gen_even_slices(X.shape[0], n_jobs)
#     455             )
#     456         else:
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/miniconda/envs/MG/lib/python3.7/site-packages/sklearn/neighbors/base.py in _tree_query_parallel_helper(tree, data, n_neighbors, return_distance)
#     289     under PyPy.
#     290     """
# --> 291     return tree.query(data, n_neighbors, return_distance)
#     292
#     293
#
# KeyboardInterrupt:

# %% [markdown]
# ## Chen predictions

# %%
chen_cell_activations = marker_model.predict(chen_data)

# %%
saly.get_results(chen_labels, chen_cell_activations, markers, marker_aliases)
# Out:
# Correct predictions: 4369 out of 5979 (73.07%)

# %%
saly.get_average_auc(chen_labels, chen_cell_activations, markers, marker_aliases)
# Out:
# Average ROC AUC: 0.5

# %%
saly.plot_activation_distribution(chen_cell_activations, markers,
                                  title='Average distribution of Chen cell type activations')

# %%
saly.draw_confusion_matrix(chen_labels, chen_cell_activations, markers, marker_aliases)

# %%
saly.draw_comparison([chen_cell_activations, chen_labels], [unseen_cell_activations, unseen_labels],
                     tsne, colours=colours,
                     graph_title='Combined cell activations of chen and unseen cell type activations')

# %% [markdown]
# # Reconstruction

# %%
reconstruction = model.predict(chen_data)[1]
reconstruction = pd.DataFrame(reconstruction, columns=chen_data.columns)
reconstructed_cell_activations = marker_model.predict(reconstruction)

# %%
saly.get_results(chen_labels, reconstructed_cell_activations, markers, marker_aliases)
# Out:
# Correct predictions: 5181 out of 5979 (86.65%)

# %%
saly.get_average_auc(chen_labels, reconstructed_cell_activations, markers, marker_aliases)
# Out:
# Average ROC AUC: 0.5

# %%
saly.plot_activation_distribution(reconstructed_cell_activations, markers,
                                  title='Average distribution of reconstructed Chen cell type activations')

# %% [markdown]
# # Reconstruction of Unseen Cells

# %%
reconstructed_unseen = model.predict(unseen_data)[1]
reconstructed_unseen = pd.DataFrame(reconstructed_unseen, columns=unseen_data.columns)
reconstructed_unseen_activation = marker_model.predict(reconstructed_unseen)

# %%
saly.get_results(unseen_labels, reconstructed_unseen_activation, markers, marker_aliases)
# Out:
# Correct predictions: 0 out of 3708 (0.0%)

# %%
saly.get_average_auc(unseen_labels, reconstructed_unseen_activation, markers, marker_aliases)
# Out:
# Average ROC AUC: 0.513

# %%
saly.plot_activation_distribution(reconstructed_unseen_activation, markers,
                                  title='Average distribution of reconstructed Chen cell type activations')
